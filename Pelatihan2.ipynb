# %% [markdown]
# # Bekerja dengan File

# %% [markdown]
# File TXT

# %%
filepath = '/content/'

# %%
filetxt ='cda_class_not_clean.txt'
with open(filepath+filetxt, 'r') as file:
  # print(file)
  for line in file:
    print(line)
  # print(file.read())
# Out:
# registration_id;name;email;phone;age;city;province;active;class;score
#
# RK20202395;Arief;arief@hotmail.com;628618317;41;Madiun;Jawa Timur;1;5;60.0
#
# RK20202355;Amalia;amalia@hotmail.com;628947349;56;Batam;Kepulauan Riau;1;6;63.0
#
# RK20202352;Putu;putu@gmail.com;628601097;42;Malang;Jawa Timur;1;5;69.0
#
# RK20202350;Citra;citra@hotmail.com;628965407;36;Surakarta;Jawa Tengah;1;4;69.0
#
# RK20202371;Budi;budi@google.com;628613620;56;Batam;Kepulauan Riau;1;6;65.0
#
# RK20202354;Fajar;fajar@gmail.com;628172162;34;Salatiga;Jawa Tengah;0;4;85.0
#
# RK20202385;Indra;indra@gmail.com;628455732;33;Purwokerto;Jawa Tengah;1;4;60.0
#
# RK20202387;Intan;intan@gmail.com;628476879;34;Salatiga;Jawa Tengah;0;4;98.0
#
# RK20202406;Kusuma;kusuma@gmail.com;628012212;51;Palangkaraya;Kalimantan Tengah;1;6;
#
# RK20202366;Deden;deden@google.com;628971836;20;Sungai Penuh;Jambi;1;2;91.0
#
# RK20202433;Tuti;tuti@google.com;628263541;46;Surabaya;Jawa Timur;1;5;0.0
#
# ...

# %%
with open(filepath+filetxt, 'r') as file:
  print(type(file))
# Out:
# <class '_io.TextIOWrapper'>

# %% [markdown]
# File CSV

# %%
import csv

filecsv = 'cda_customer.csv'
with open(filepath+filecsv, mode='r') as file:
  # print(file)
  reader = csv.reader(file)
  # print(type(reader))
  # print(reader)
  for row in reader:
    print(row)

# %% [markdown]
# File JSON

# %%
import json

filejson = 'city-data.json'
with open(filepath+filejson, 'r') as file:

  read_json = json.load(file)
  data_properties = read_json['features'][1]['properties']
  # print(read_json)
  # print(read_json['features'][0])
  # print(type(read_json))
  # print(type(read_json['features'][0]))
  print(data_properties)
# Out:
# {'name': 'Tokyo', 'population': '13.35', 'country': 'Japan', 'coastal': 'true'}

# %% [markdown]
# # Struktur Data Pandas

# %% [markdown]
# Series

# %%
import pandas as pd

angka = [1,2,3,4.5,5]
identitas = {
    'Nama': 'Gamal',
    'Umur':29,
    'Alamat':'Jln. Tambak'
}

# %%
print(type(angka))
pd.Series(angka)
# Out:
# <class 'list'>
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.5
# 4    5.0
# dtype: float64

# %%
print(type(identitas))
pd.Series(identitas)
# Out:
# <class 'dict'>
# Nama            Gamal
# Umur               29
# Alamat    Jln. Tambak
# dtype: object

# %%
nilai_pajak = [10,20,30]
label_pajak = ['PPh 21', 'PPN', 'PBB']

series_pajak = pd.Series(data=nilai_pajak, index=label_pajak)
series_pajak
# Out:
# PPh 21    10
# PPN       20
# PBB       30
# dtype: int64

# %% [markdown]
# DataFrame

# %%
data_pengeluaran = {
    'Tanggal':['2025-05-01', '2025-05-01', '2025-05-02', '2025-05-02'],
    'Kategori':['Makanan', 'Transportasi', 'Makanan', 'Hiburan'],
    'Nominal (Rp)':[25000, 10000, 50000, 30000]
}

df_pengeluaran = pd.DataFrame(data_pengeluaran)

# %%
df_pengeluaran.head(2)
# Out:
#       Tanggal      Kategori  Nominal (Rp)
# 0  2025-05-01       Makanan         25000
# 1  2025-05-01  Transportasi         10000

# %%
df_pengeluaran.tail(2)
# Out:
#       Tanggal Kategori  Nominal (Rp)
# 2  2025-05-02  Makanan         50000
# 3  2025-05-02  Hiburan         30000

# %%
df_pengeluaran.dtypes
# Out:
# Tanggal         object
# Kategori        object
# Nominal (Rp)     int64
# dtype: object

# %%
df_pengeluaran.shape
# Out:
# (4, 3)

# %%
df_pengeluaran
# Out:
#       Tanggal      Kategori  Nominal (Rp)
# 0  2025-05-01       Makanan         25000
# 1  2025-05-01  Transportasi         10000
# 2  2025-05-02       Makanan         50000
# 3  2025-05-02       Hiburan         30000

# %%
df_csv = pd.read_csv(filepath+filecsv,sep=',',skiprows=6)
df_csv
# Out:
#     id_pelanggan                         nama  \
# 0              1  Fakhrul Fandy Widyaningtias
# 1              2          Ferdiansyah Amalina
# 2              3            Ficky Rizkyananta
# 3              4             Singgih Kharisma
# 4              5             Jeremiah Dinanti
# ..           ...                          ...
# 80            81                Desi Fauziyah
# 81            82       Tresna Rianita Prasojo
# 82            83               Rarahayu Verev
# 83            84                Janiar Satria
# 84            85               Retno Maulinda
#
#                                     email     telepon  umur bulan_lahir  \
# 0   fakhrulfandywidyaningtias@outlook.com  6285244454    27        Juni
# 1            ferdiansyahamalina@yahoo.com  6285244688    31     Agustus
# 2            fickyrizkyananta@hotmail.com  6285244922    15    Februari
# 3             singgihkharisma@hotmail.com  6285245156    49     Januari
# ...

# %%
with open(filepath+filetxt, 'r') as file:
  df = pd.read_csv(file,delimiter=';')
  print(df.info())
  # print(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   registration_id  169 non-null    object
#  1   name             169 non-null    object
#  2   email            162 non-null    object
#  3   phone            169 non-null    int64
#  4   age              169 non-null    int64
#  5   city             157 non-null    object
#  6   province         169 non-null    object
#  7   active           169 non-null    int64
#  8   class            169 non-null    int64
#  9   score            165 non-null    float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 13.3+ KB
# None

# %%
df = pd.read_json(filepath+filejson)
features = df['features'].values.tolist()
df_features = pd.DataFrame(features)
properties = df_features['properties'].values.tolist()
df_properties = pd.DataFrame(properties,index=range(1,len(properties)+1))
df_properties
# Out:
#               name population                country coastal
# 1           Berlin      3.375                Germany   false
# 2            Tokyo      13.35                  Japan    true
# 3        New Delhi       9.88                  India   false
# 4      Los Angeles       3.92          United States    true
# 5           Boston       4.18          United States    true
# 6       Copenhagen       1.26                Denmark    true
# 7      Mexico City       8.85                 Mexico   false
# 8        Amsterdam       1.32            Netherlands   false
# 9          Bangkok       8.28               Thailand    true
# 10          Sydney       4.84              Australia    true
# 11          Prague       1.26         Czech Republic   false
# 12       Cape Town       0.43           South Africa    true
# 13          Taipei       2.70                 Taiwan    true
# 14       Hong Kong       7.23                  China    true
# ...

# %% [markdown]
# Memilih baris berdasarkan index

# %%
a = df_properties['coastal'] == 'false'
b = df_properties['country'] == 'Germany'
df_is_coastal = df_properties[(a) & (b)]
df_is_coastal
# Out:
#      name population  country coastal
# 1  Berlin      3.375  Germany   false

# %%
df_csv[(df_csv['penipu'] == 1)]
# Out:
#     id_pelanggan               nama                         email     telepon  \
# 16            17  Rifqy Butar-butar    rifqybutar-butar@yahoo.com  6289625971
# 17            18       Wahyu Hayati         wahyuhayati@gmail.com  6289627184
# 57            58    Nadia Persadani  nadiapersadani@roketmail.com  6287833759
# 72            73    Natasha Fadholi      natashafadholi@gmail.com  6285282083
#
#     umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  penipu  \
# 16    30   September         2012-01-14                   1       1
# 17    23    Desember         2012-09-15                   1       1
# 57    25        Juli         2012-10-26                   1       1
# 72    49       April         2013-02-08                   1       1
#
#     pengguna_aktif
# 16               1
# 17               1
# 57               1
# 72               1

# %%
df_csv[(df_csv['umur'] > 30) & (df_csv['pengguna_aktif'] == 1)]
# Out:
#     id_pelanggan                    nama                               email  \
# 1              2     Ferdiansyah Amalina        ferdiansyahamalina@yahoo.com
# 3              4        Singgih Kharisma         singgihkharisma@hotmail.com
# 5              6         Ridhwan Noerani          ridhwannoerani@hotmail.com
# 6              7         Okky Oktaviaman        okkyoktaviaman@roketmail.com
# 9             10               Bob Arisa                  bobarisa@yahoo.com
# 10            11              Omar Afini                 omarafini@gmail.com
# 11            12          Sutrisno Rizal           sutrisnorizal@outlook.com
# 13            14        Lintang Bertauli           lintangbertauli@gmail.com
# 14            15    Reynard Ramadhansyah       reynardramadhansyah@gmail.com
# 15            16           Kevin Ningsih          kevinningsih@roketmail.com
# 18            19          Andi Mayasopha             andimayasopha@yahoo.com
# ...

# %%
bln_tertentu = df_csv['bulan_lahir'].isin(['Januari','Maret'])
df_csv[df_csv['bulan_lahir'].isin(['Januari'])]
df_csv.query('bulan_lahir in ("Januari","Maret")')
# Out:
#     id_pelanggan                    nama                               email  \
# 3              4        Singgih Kharisma         singgihkharisma@hotmail.com
# 4              5        Jeremiah Dinanti       jeremiahdinanti@roketmail.com
# 5              6         Ridhwan Noerani          ridhwannoerani@hotmail.com
# 6              7         Okky Oktaviaman        okkyoktaviaman@roketmail.com
# 11            12          Sutrisno Rizal           sutrisnorizal@outlook.com
# 12            13           Hilman Azalia            hilmanazalia@hotmail.com
# 21            22         Thomas Geryance        thomasgeryance@roketmail.com
# 22            23        Muhamad Pramanda         muhamadpramanda@outlook.com
# 23            24           Ramanta Pasha              ramantapasha@gmail.com
# 24            25           Sakti Hasaniy            saktihasaniy@outlook.com
# 29            30         Herdaru Junaidi          herdarujunaidi@outlook.com
# ...

# %%
df_pelanggan = pd.read_csv(filepath+filecsv,skiprows=6)
a = (df_pelanggan['umur'] >= 25) & (df_pelanggan['umur'] <= 40)
b = df_pelanggan['penipu'] == 0
c = df_pelanggan['pengguna_aktif'] == 1
d = df_pelanggan['konfirmasi_telepon'] == 1
e = df_pelanggan['bulan_lahir'].isin(['Maret','Juni', 'September'])
pelanggan = df_pelanggan[(a) & (b) & (c) & (d) & (e)].filter(items=['nama','email','umur','bulan_lahir','telepon'])
print(f'Jumlah WP Potensial Baru : {pelanggan["nama"].count()} dari {df_pelanggan["nama"].count()}')
print(pelanggan['umur'].describe())
pelanggan
# Out:
# Jumlah WP Potensial Baru : 9 dari 85
# count     9.000000
# mean     32.555556
# std       4.558265
# min      25.000000
# 25%      31.000000
# 50%      33.000000
# 75%      35.000000
# max      40.000000
# Name: umur, dtype: float64
#                            nama                                  email  umur  \
# 0   Fakhrul Fandy Widyaningtias  fakhrulfandywidyaningtias@outlook.com    27
# 6               Okky Oktaviaman           okkyoktaviaman@roketmail.com    35
# 18               Andi Mayasopha                andimayasopha@yahoo.com    36
# 24                Sakti Hasaniy               saktihasaniy@outlook.com    31
# 30                 Eka Tiodimar              ekatiodimar@roketmail.com    40
# 38                  Izhar Halim                   izharhalim@gmail.com    32
# 58            Rayhana Hidayatul           rayhanahidayatul@hotmail.com    25
# 62                Rocitha Mufti             rocithamufti@roketmail.com    33
# ...

# %%
# Out:
# array([27, 35, 36, 31, 40, 32, 25, 33, 34])
